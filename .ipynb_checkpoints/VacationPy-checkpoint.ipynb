# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  adamstown -25.0660 -130.1015     21.60        77          98
# 1        1   thompson  55.7435  -97.8558     21.09        49          40
# 2        2     acarau  -2.8856  -40.1200     29.22        62           6
# 3        3     turpan  42.9333   89.1667     36.13        16          14
# 4        4     ca mau   9.1769  105.1500     25.78        88         100
#
#    Wind Speed Country      Date
# 0        5.44      PN  23-07-18
# 1        1.54      CA  23-07-18
# 2        8.21      BR  23-07-18
# 3        1.93      CN  23-07-18
# 4        4.12      VN  23-07-18

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot=city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo=True,
    tiles='EsriNatGeo',
    frame_width=700,
    frame_height=500,
    size='Humidity',
    color='City',
    scale=0.8
)                

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
temperature = (city_data_df['Max Temp'] >= 18) & (city_data_df['Max Temp'] <= 24)
wind_speed = (city_data_df['Wind Speed'] < 4)
cloudiness_new = (city_data_df['Cloudiness'] >= 0) & (city_data_df['Cloudiness'] <= 20)
humidity_new = (city_data_df['Humidity'] >= 30) & (city_data_df['Humidity'] <= 60)
ideal = city_data_df.loc[temperature & wind_speed & cloudiness_new & humidity_new]

# Drop any rows with null values
ideal.dropna(how='any')

# Display sample data
print(len(ideal))
ideal.head()
# Out:
# 19
#      City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 14        14     saurimo  -9.6608   20.3916     20.09        31           5
# 40        40     horsham  51.0640   -0.3272     19.30        60           0
# 119      119    penafiel  41.2084   -8.2829     22.41        58           5
# 130      130     colonia  50.9333    6.9500     23.48        46           0
# 229      229  revelstoke  50.9832 -118.2023     22.01        56          20
#
#      Wind Speed Country      Date
# 14         2.03      AO  23-07-18
# 40         3.60      GB  23-07-18
# 119        2.47      PT  23-07-18
# 130        1.54      DE  23-07-18
# 229        1.03      CA  23-07-18

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

hotel_df = pd.DataFrame(ideal.loc[:, ['City', 'Country', 'Lat', 'Lng', 'Humidity']]).copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 14      saurimo      AO  -9.6608   20.3916        31
# 40      horsham      GB  51.0640   -0.3272        60
# 119    penafiel      PT  41.2084   -8.2829        58
# 130     colonia      DE  50.9333    6.9500        46
# 229  revelstoke      CA  50.9832 -118.2023        56

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000

params = {
     "categories":"accommodation.hotel",
     "limit":1,
     "apiKey":geoapify_key    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat=hotel_df.loc[index,'Lat']
    lng=hotel_df.loc[index,'Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# saurimo - nearest hotel: Complexo Hoteleiro de Saurimo
# horsham - nearest hotel: Premier Inn
# penafiel - nearest hotel: No hotel found
# colonia - nearest hotel: Wasserturm Hotel Cologne
# revelstoke - nearest hotel: Grizz Hotel
# kamloops - nearest hotel: No hotel found
# port saint john's - nearest hotel: Outback Inn
# richards bay - nearest hotel: Bon Hotel Waterfront
# turgen - nearest hotel: No hotel found
# nchelenge - nearest hotel: No hotel found
# ishqoshim - nearest hotel: Hotel Restaurant
# havre - nearest hotel: Le Relais des 2 Normandies
# altay - nearest hotel: Sunshine Holiday Hotel
# bozeman - nearest hotel: Kimpton Armory Hotel Bozeman
# pisco - nearest hotel: La Portada
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# lata - nearest hotel: Residencial Botânico
# coquimbo - nearest hotel: Hotel Iberia
# cuamba - nearest hotel: Pensao Cariaco
#                   City Country      Lat       Lng  Humidity  \
# 14             saurimo      AO  -9.6608   20.3916        31
# 40             horsham      GB  51.0640   -0.3272        60
# 119           penafiel      PT  41.2084   -8.2829        58
# 130            colonia      DE  50.9333    6.9500        46
# 229         revelstoke      CA  50.9832 -118.2023        56
# 233           kamloops      CA  50.6665 -120.3192        47
# 237  port saint john's      ZA -31.6229   29.5448        47
# 240       richards bay      ZA -28.7830   32.0377        42
# 242             turgen      KZ  43.4006   77.5933        35
# 248          nchelenge      ZM  -9.3451   28.7340        55
# 267          ishqoshim      TJ  36.7248   71.6133        38
# 315              havre      FR  49.5833    0.3333        60
# 353              altay      CN  47.8667   88.1167        41
# 377            bozeman      US  45.6796 -111.0386        36
# 378              pisco      PE -13.7000  -76.2167        60
# 385      fort mcmurray      CA  56.7268 -111.3810        53
# 432               lata      PT  40.1629   -8.3327        56
# 548           coquimbo      CL -29.9533  -71.3436        59
# 559             cuamba      MZ -14.8031   36.5372        53
#
#                         Hotel Name
# 14   Complexo Hoteleiro de Saurimo
# 40                     Premier Inn
# 119                 No hotel found
# 130       Wasserturm Hotel Cologne
# 229                    Grizz Hotel
# 233                 No hotel found
# 237                    Outback Inn
# 240           Bon Hotel Waterfront
# 242                 No hotel found
# 248                 No hotel found
# 267               Hotel Restaurant
# 315     Le Relais des 2 Normandies
# 353         Sunshine Holiday Hotel
# 377   Kimpton Armory Hotel Bozeman
# 378                     La Portada
# 385         Nomad Hotel and Suites
# 432           Residencial Botânico
# 548                   Hotel Iberia
# 559                 Pensao Cariaco

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.8,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    hover_cols = ["Hotel Name", "Country"]
)
    

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
